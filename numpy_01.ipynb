# %%
import numpy as np

# %%
a=np.array([2,3,4])

# %%
a.ndim #N dim returns the dimention of numpy array
# Out:
# 1

# %%
#np arrange help use to create an array based on start stop and increment
arr=np.arange(2,11,2)

# %%
print(arr)
# Out:
# [ 2  4  6  8 10]

# %%
#linspace helps us to create evenly spaced numpy array
linsSpaceNumpyarray=np.linspace(2,10,2)

# %%
print(linsSpaceNumpyarray)
# Out:
# [ 2. 10.]

# %%
#Logs space helps us to create power array
np.logspace(0,2,6)
# Out:
# array([  1.        ,   2.51188643,   6.30957344,  15.84893192,
#         39.81071706, 100.        ])

# %%
#zeros array create arays of 0
arr=np.zeros(8)

# %%
print(arr)
# Out:
# [0. 0. 0. 0. 0. 0. 0. 0.]

# %%
#Ones array
arr=np.ones(9)

# %%
print(arr)
# Out:
# [1. 1. 1. 1. 1. 1. 1. 1. 1.]

# %%
#array of numbers of user choice
arr=np.full(8,5)

# %%
print(arr)
# Out:
# [5 5 5 5 5 5 5 5]

# %%
arr=np.empty(2)
print(arr)
# Out:
# [  1. 100.]
