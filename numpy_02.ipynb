# %% [markdown]
# <a href="https://colab.research.google.com/github/aditya-khaparde28/Python-Numpy/blob/main/numpy_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
#Random Array in Numpy Uniformly destributed
arr=np.random.rand(1,4)

# %%
print(arr)
# Out:
# [[0.60885767 0.58869534 0.73736611 0.1950989 ]]

# %%
#Random Array In Numpy normal distributed
arr=np.random.randn(1,4)
print(arr)
# Out:
# [[ 0.80745053 -0.92573509 -1.12139786  0.39328523]]

# %%
#Numpy-Input to below function is (start,stop,number of elements)
arr=np.random.randint(1,10,size=4)
print(arr)
# Out:
# [8 5 5 8]

# %%
arr=np.random.random_integers
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_24517/2256876534.py in <cell line: 0>()
# ----> 1 arr=np.random.random_integers
#
# NameError: name 'np' is not defined

# %%
arr=np.array([1,2.3,3])

# %%
print(arr)
# Out:
# [1.  2.3 3. ]

# %%
lst=["priya","sneha","vaishu"]

# %%
arr=np.array(lst)
print(arr)
# Out:
# ['priya' 'sneha' 'vaishu']

# %%
#Creating array with different datatypes

# %%
arr=np.array([1,2,2],np.float64)
arr
# Out:
# array([1., 2., 2.])

# %%
arr=np.array([1,2.,22],np.int64)

# %%
arr
# Out:
# array([ 1,  2, 22])

# %%
#Type casting one array to another
arr=np.array([1,2,3])
arr
# Out:
# array([1, 2, 3])

# %%
arr2=np.astype(arr,np.float64)

# %%
arr2
# Out:
# array([1., 2., 3.])

# %%
print(arr2.shape)
# Out:
# (3,)

# %%
arr2.reshape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3681/247863994.py in <cell line: 0>()
# ----> 1 arr2.reshape()
#
# TypeError: reshape() takes exactly 1 argument (0 given)

# %%
arr=np.array([1,2,3,4,5,6])

# %%
arr.reshape(2,3)
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
#Ravel is used to convert any particular array to 1D Array
arr=np.array([[1,2,2],
             [2,2,2]])

# %%
arr.ravel
# Out:
# <function ndarray.ravel>

# %%
print(arr.ravel)
# Out:
# <built-in method ravel of numpy.ndarray object at 0x786a0b730c30>

# %%
ravel=arr.ravel()

# %%
print(ravel)
# Out:
# [1 2 2 2 2 2]

# %%
print(arr)
# Out:
# [[1 2 2]
#  [2 2 2]]

# %%
#Flatten
flatton=arr.flatten()
print(flatton)
# Out:
# [1 2 2 2 2 2]

# %%
#Arithmetic

# %%
arr1=np.array([1,2,3])

# %%
arr2=np.array([2,4,6])

# %%
print(arr1+arr2)
# Out:
# [3 6 9]

# %%
print(arr1-arr2)
# Out:
# [-1 -2 -3]

# %%
print(arr1/arr2)
# Out:
# [0.5 0.5 0.5]

# %%
print(arr1*arr2)
# Out:
# [ 2  8 18]

# %%
print(arr1//arr2)
# Out:
# [0 0 0]

# %%
arr=[2,3,4]

# %%
arr[0,1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_5846/2169348051.py in <cell line: 0>()
# ----> 1 arr[0,1]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
#Array Slice
arr[0:1]
# Out:
# [2]

# %%
arr=[2,4,6,8,20,35,66]

# %%
arr[1:4:2]
# Out:
# [4, 8]

# %%
#Multidimensinal Slicing
arr=np.array([[2,4,6],
     [4,7,8],
     [22,12,2]])

# %%
arr[0:3]
# Out:
# [[2, 4, 6], [4, 7, 8], [22, 12, 2]]

# %%
arr[0:2]
# Out:
# [[2, 4, 6], [4, 7, 8]]

# %%
arr[0:2:2]
# Out:
# [[2, 4, 6]]

# %%
#Transpose of matrix
print(arr.transpose())
# Out:
# [[ 2  4 22]
#  [ 4  7 12]
#  [ 6  8  2]]
